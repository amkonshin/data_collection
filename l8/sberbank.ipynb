# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import numpy as np

# %%
df=pd.read_csv('opendata.csv',encoding='cp1251')

# %%
df.head()
# Out:
#                                            name  region        date   value
# 0  Количество заявок на потребительские кредиты  Россия  2013-01-15  571147
# 1  Количество заявок на потребительские кредиты  Россия  2013-02-15  504508
# 2  Количество заявок на потребительские кредиты  Россия  2013-03-15  628803
# 3  Количество заявок на потребительские кредиты  Россия  2013-04-15  836054
# 4  Количество заявок на потребительские кредиты  Россия  2013-05-15  867235

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74842 entries, 0 to 74841
# Data columns (total 4 columns):
# name      74842 non-null object
# region    74842 non-null object
# date      74842 non-null object
# value     74842 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 1.4+ MB

# %%
#pd.to_datetime(df['date'])

# %%
df['name'].unique()
# Out:
# array(['Количество заявок на потребительские кредиты',
#        'Средняя сумма заявки на потребительский кредит',
#        'Количество заявок на ипотечные кредиты',
#        'Средняя сумма заявки на ипотечный кредит',
#        'Количество новых депозитов', 'Средняя сумма нового депозита',
#        'Средняя зарплата', 'Средняя пенсия',
#        'В среднем руб. на текущем счете на человека',
#        'В среднем депозитов в руб. на человека',
#        'Средние расходы по картам', 'Средний чек в формате Фастфуд',
#        'Средний чек в формате Ресторан',
#        'Средние траты в ресторане фастфуд', 'Средние траты в ресторане'],
#       dtype=object)

# %%
user_region='Алтайский край'
user_name='Средняя зарплата'

# %%
search=df.loc[(df['name']==user_name) & (df['region']==user_region)]

# %%
search.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 34487 to 34535
# Data columns (total 4 columns):
# name      49 non-null object
# region    49 non-null object
# date      49 non-null object
# value     49 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 1.3+ KB

# %%
search
# Out:
#                    name          region        date  value
# 34487  Средняя зарплата  Алтайский край  2015-01-15  11218
# 34488  Средняя зарплата  Алтайский край  2015-02-15  14545
# 34489  Средняя зарплата  Алтайский край  2015-03-15  14183
# 34490  Средняя зарплата  Алтайский край  2015-04-15  17133
# 34491  Средняя зарплата  Алтайский край  2015-05-15  15458
# 34492  Средняя зарплата  Алтайский край  2015-06-15  17849
# 34493  Средняя зарплата  Алтайский край  2015-07-15  17321
# 34494  Средняя зарплата  Алтайский край  2015-08-15  15791
# 34495  Средняя зарплата  Алтайский край  2015-09-15  15994
# 34496  Средняя зарплата  Алтайский край  2015-10-15  16205
# 34497  Средняя зарплата  Алтайский край  2015-11-15  16165
# 34498  Средняя зарплата  Алтайский край  2015-12-15  24377
# 34499  Средняя зарплата  Алтайский край  2016-01-15  13146
# 34500  Средняя зарплата  Алтайский край  2016-02-15  16476
# 34501  Средняя зарплата  Алтайский край  2016-03-15  16663
# ...

# %%
plt.plot(search['date'],search['value'])

plt.xticks([i for i in range(0,search['date'].size,3)])
plt.tick_params(axis= 'x', rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
